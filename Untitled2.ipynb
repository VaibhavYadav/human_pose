# %%
import torchvision.transforms as transforms
from datasets import LSPDataset
import torch.utils.data as data
import torch.nn.functional as F

# %%
lsp = LSPDataset('./dataset/lsp_dataset/', 'points')

# %%
dataloader = data.DataLoader(lsp, 10)

# %%
t0 = transforms.ToPILImage()
t1 = transforms.Resize(64, 64)
for i in dataloader:
    break

# %%
t0(F.interpolate(i[0], 64)[0])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1B8CD5D9820>
