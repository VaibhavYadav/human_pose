# %%
from datasets import LSPDataset, LSPExtendedDataset
from vis import show_pose, show_pose_from_hmap, show_hmap
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision.transforms import transforms

# %%
d = LSPExtendedDataset('./dataset/lspet_dataset/', 'heatmap')

# %%
a, b, c = d.__getitem__(np.random.randint(len(d)))
show_hmap(a, b)
show_pose_from_hmap(a, b)
